# %% [markdown]
# #Configuration

# %%
atr = "http://www.attheraces.com"

# Beautiful Soup
import lxml.etree
import lxml.html
import urllib2
from bs4 import BeautifulSoup

# %% [markdown]
# #SQLite

# %%
from datetime import date
from pony.orm import *

db = Database("sqlite", "/home/jaime/pony/testdb3", create_db=True)

class RaceDay(db.Entity):
    Date = PrimaryKey(date)
    meetings = Set("Meeting")

class Course(db.Entity):
    courseName = PrimaryKey(str)
    course_distances = Set("CourseDistance")
    meetings = Set("Meeting")
    
    @staticmethod
    def find(name):
        try:
            c = Course[name]
            return c
        except:
            c = Course(courseName = name)
            commit()
            return c

class Distance(db.Entity):
    Furlongs = PrimaryKey(int)
    course_distances = Set("CourseDistance")

class CourseDistance(db.Entity):
    course = Required(Course)
    distance = Required(Distance)
    PrimaryKey(course,distance)
    races = Set("Race")

class Meeting(db.Entity):
    race_day = Required(RaceDay)
    course = Required(Course)
    PrimaryKey(race_day, course)
    races = Set("Race")
    ground = Optional(str)
    
    
    @staticmethod
    def find(rd, course):
        try:
            c = Meeting[rd, course]
            return c
        except:
            c = Meeting(race_day = rd, course = course)
            commit()
            return c

class Race(db.Entity):
    meeting = Required(Meeting)
    meeting_race_day = date
    course_distance = Required(CourseDistance)
    runners = Set("Runner")

class Runner(db.Entity):
    race = Required(Race)
    horse = Required("Horse")
    PrimaryKey(race,horse)
    race_comment = Optional("RaceComment")

class Horse(db.Entity):
    horseName = PrimaryKey(str, 20)
    runners = Set(Runner)
    horse_comment = Optional("HorseComment")
    comments = Set("Comment")

class User(db.Entity):
    comments = Set("Comment")

class Comment(db.Entity):
    user = Required(User)
    horseName = Required(Horse)

class RaceComment(db.Comment):
    
    runner = Required(Runner)

class HorseComment(db.Comment):
    horse = Required(Horse)

sql_debug(True)
db.generate_mapping(create_tables=True)
# Out:
# GET NEW CONNECTION
# RELEASE CONNECTION
# GET CONNECTION FROM THE LOCAL POOL
# PRAGMA foreign_keys = false
# BEGIN IMMEDIATE TRANSACTION
# SELECT "Comment"."id", "Comment"."user", "Comment"."horseName", "Comment"."classtype", "Comment"."runner_race", "Comment"."runner_horse", "Comment"."horse"
# FROM "Comment" "Comment"
# WHERE 0 = 1
#
# SELECT "Course"."courseName"
# FROM "Course" "Course"
# WHERE 0 = 1
#
# SELECT "CourseDistance"."course", "CourseDistance"."distance"
# FROM "CourseDistance" "CourseDistance"
# WHERE 0 = 1
#
# SELECT "Distance"."Furlongs"
# FROM "Distance" "Distance"
# WHERE 0 = 1
#
# SELECT "Horse"."horseName", "Horse"."horse_comment"
# FROM "Horse" "Horse"
# WHERE 0 = 1
#
# SELECT "Meeting"."race_day", "Meeting"."course", "Meeting"."ground"
# FROM "Meeting" "Meeting"
# WHERE 0 = 1
#
# SELECT "Race"."id", "Race"."meeting_race_day", "Race"."meeting_course", "Race"."course_distance_course", "Race"."course_distance_distance"
# FROM "Race" "Race"
# WHERE 0 = 1
#
# SELECT "RaceDay"."Date"
# FROM "RaceDay" "RaceDay"
# WHERE 0 = 1
#
# SELECT "Runner"."race", "Runner"."horse"
# FROM "Runner" "Runner"
# WHERE 0 = 1
#
# SELECT "User"."id"
# FROM "User" "User"
# WHERE 0 = 1
#
# COMMIT
# PRAGMA foreign_keys = true
# CLOSE CONNECTION

# %% [markdown]
# #Objects
# ###Race

# %%
class ATRRace(object):
    
    def __init__(self):
        self.soups = None
        self.meeting = 'Beverley'
        # data = 17:05 - 5f 
        # link = /card.aspx?raceid=813020&meetingid=65660&date=2014-04-24&ref=mainracenavigation&refsite=&nav=racecards
        # http://www.attheraces.com/card.aspx?raceid=813636&meetingid=65728&date=2014-04-28&ref=fixtures&refsite=&nav=racecards
        
        self.time = "13:55"
        self.distance = "5f"
        self.link = "/card.aspx?raceid=813708&meetingid=65737&date=2014-04-29&ref=fixtures&refsite=&nav=racecards"
        #print "Link for each race:", len(race_data) == len(race_link)
        
    def soup(self):
        if self.soups:
            print "oops"
            return self.soups
        else:
            address = atr + self.link
            url = urllib2.urlopen(address)
            content = url.read()
            self.soups = BeautifulSoup(content)
            return self.soups
            
        
    def __str__(self):
        s ="Course: " + self.meeting.course + " Time: " + self.time + " Distance: " + self.distance + "\nlink: " + self.link
        return s

# %% [markdown]
# #Code
# #### Find Race Name and Course

# %%
race = ATRRace()

# %%
soup = race.soup()

# %% [markdown]
# 1. have date create RaceDay

# %%
import time    

today = time.strftime('%Y-%m-%d')
print today

rd = RaceDay(Date = today)
# Out:
# 2014-04-29

# %%
commit()
# Out:
# GET NEW CONNECTION
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "RaceDay" ("Date") VALUES (?)
# ['2014-04-29']
#
# COMMIT

# %%
h3 = soup.findAll('h3')
for h in h3:
    print "--",h.text
    
time, courseName = h3[1].text.split(',')[0].split(" ")
dist = h3[2].text
print time, courseName
# Out:
# -- Please enable JavaScript to login to At The Races Need further assistance?
# -- 20:20 Newcastle,
#     29 Apr 2014
# -- 5f
# 20:20 Newcastle

# %% [markdown]
# 2. Find Course
# 3. Find Meeting

# %%
c = Course.find(courseName)
print c

m = Meeting.find(rd.Date, c)
print m
# Out:
# GET NEW CONNECTION
# SWITCH TO AUTOCOMMIT MODE
# SELECT "courseName"
# FROM "Course"
# WHERE "courseName" = ?
# [u'Newcastle']
#
# Course['Newcastle']
# SELECT "race_day", "course", "ground"
# FROM "Meeting"
# WHERE "race_day" = ?
#   AND "course" = ?
# ['2014-04-29', u'Newcastle']
#
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Meeting" ("race_day", "course", "ground") VALUES (?, ?, ?)
# ['2014-04-29', u'Newcastle', u'']
#
# COMMIT
# Meeting[RaceDay[datetime.date(2014, 4, 29)],Course['Newcastle']]

# %% [markdown]
# 4. Distance - convert 1m 5f

# %%
def convertDistance(string):
    furlongs = 0
    
    tokens = string.split()
    
    if len(tokens) > 1:
        furlongs = furlongs + 8*int(tokens[0][0])
        
    return furlongs + int(tokens[-1][0])

print convertDistance("1m 5f")
print convertDistance("5f")
    
d = convertDistance(dist)

print d

d = Distance(Furlongs = distance)
# Out:
# ---------------------------------------------------------------------------
# CacheIndexError                           Traceback (most recent call last)
# <ipython-input-117-bf3b7ca3db5b> in <module>()
#      16 print d
#      17
# ---> 18 d = Distance(Furlongs = distance)
#      19 cd = CourseDistance(course = c, distance = d)
#
# /usr/lib/python2.7/site-packages/pony/orm/core.pyc in __new__(entity, *args, **kwargs)
#
# /usr/lib/python2.7/site-packages/pony/orm/core.pyc in _new_(entity, pkval, status, for_update, undo_funcs)
#    3214             if entity._pk_is_composite_: pkval = ', '.join(str(item) for item in pkval)
#    3215             throw(CacheIndexError, 'Cannot create %s: instance with primary key %s already exists'
# -> 3216                              % (obj.__class__.__name__, pkval))
#    3217         elif obj.__class__ is entity: pass
#    3218         elif issubclass(obj.__class__, entity): pass
#
# /usr/lib/python2.7/site-packages/pony/utils.pyc in throw(exc_type, *args, **kwargs)
#     124         raise exc
#     125     else:
# --> 126         raise exc  # Set "pony.options.CUT_TRACEBACK = False" to see full traceback
#     127
#     128 lambda_args_cache = {}
#
# CacheIndexError: Cannot create Distance: instance with primary key 5 already exists
# 13
# 5
# 5

# %%
cd = CourseDistance(course = c, distance = d)

# %% [markdown]
# 1. Get second table
# 2. Get table head

# %%
table = soup.findAll("table")[1]
print table.find("thead")
# Out:
# <thead>
# <tr>
# <th class="tooltip" title="Horse Number (Draw Number)" width="44">No/Drw<br/><img alt="" height="1" src="/images/spacer.gif" width="44"/></th>
# <th class="tooltip" title="The jacket and cap worn by the jockey. Silks can be generic and provided by the track or specific to one owner" width="44">Silk<br/><img alt="" height="1" src="/images/spacer.gif" width="44"/></th>
# <th class="tooltip" title="How the horse performed in it's previous outings, most recent on the right: Number=Position, F=Fell, P=Pulled Up, U=Unseated Rider,B=Brought Down,R=Refused,C=Carried Out,S=Slipped Up,/=Over A Year Between Races, -=New Season" width="45">Form<br/><img alt="" height="1" src="/images/spacer.gif" width="45"/></th>
# <th class="tooltip" title="Name of horse / (breeding) if outside race country / any extra weight for recent win / days since last ran / C=won on this course, D=won at this distance, CD=won at this course and this distance, BF=beaten favourite last time out" width="100%">Horse</th>
# <th class="tooltip" title="Age of horse / Weight carrying in stones and lbs / h=hood, v=visor, b=blinkers, es=eyeshield, ec=eyecover, t=tonguestrap, p=cheek pieces, 1=worn for first time" width="60">Age / Wt<br/><img alt="" height="1" src="/images/spacer.gif" width="60"/></th>
# <th class="tooltip" title="Jockey / Trainer" width="104">Jockey / Trainer<br/><img alt="" height="1" src="/images/spacer.gif" width="104"/></th>
# <th class="tooltip" title="Official Rating" width="30">OR</th>
# </tr>
# </thead>

# %% [markdown]
# 1. Get each horse by finding tr in tbody
# 2. There are 2 rows: horse data andtimeform

# %%
tbody = table.find("tbody")
trows = tbody.findAll("tr")
print trows[0].text
# Out:
# 1(2)iT
#
#
&lt;span class=&quot;tfstarrating&quot;&gt;Star Rating &lt;img src=&quot;/images/racecards/star_3.gif&quot; alt=&quot;&quot;/&gt;&lt;/span&gt;&lt;/div&gt;">T</a></div>
# </td>
# <td class="silk"><img alt="White, brown braces, amber cap" src="/images/silks/20140429/20140429ncs202001.png"/></td>
# <td>544371-<br/><a class="full_form" href="/form.aspx?id=2724053&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr" onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="_blank">Full form</a></td>
# <td class="horse"><a class="tooltip" href="/form.aspx?id=2724053&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr" onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for Dark Opal form"><span class="horsename">Dark Opal</span></a>
#             (IRE)
#            201 <span class="tooltip racestat" title="Won at this course and this distance">CD</span><a class="tracker_popup" href="#" id="trid2724053" title="Dark Opal">ATR Tracker</a><br/><span class="horseextrawrap"><span class="horseinfoicons"></span>b f Camacho - Dark Albatross (Sheikh Albadou)</span></td>
# <td>4 9 - 7</td>
# <td>
# <ul>
# <li class="jockey"><a class="tooltip" href="/form.aspx?id=1000071&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr&amp;type=J
#     " onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for D Tudhope form">D Tudhope</a></li>
# <li class="trainer"><a class="tooltip" href="/form.aspx?id=1000937&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr&amp;type=T
#     " onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for J R Weymes form">J R Weymes</a></li>
# </ul>
# </td>
# <td class="OR">70</td>
# </tr>
# <tr class="reviewtimeform">
# <td colspan="8"><strong>Timeform says</strong>: Won 5f handicap at Ayr when last seen in October. Should remain competitive off this mark but entitled to need her first run back this year.<br/><span class="tfstarrating">Star Rating <img alt="" src="/images/racecards/star_3.gif"/></span></td>
# </tr>
# <tr class="">
# <td class=" cloth"><span class="number draw">2<em>(9)</em></span><div class="icons"><a class="summary tooltip" href="#" title="&lt;div class='longtext'&gt;Successful at 6f and 7f on good to soft and soft ground. Finished 3l behind Red Baron when fifth of 14 at 9-1 on his latest outing at Doncaster over 5f (soft) earlier this month.&lt;/div&gt;">i</a><a class="timeform tooltip" href="#" title="&lt;div class='longtext'&gt;&lt;strong&gt;Timeform says&lt;/strong&gt;: Last 2 wins have come here. Head carriage doesn't endear him to all but he didn't run badly at Doncaster last week and should give his running once again. &lt;span class=&quot;tfstarrating&quot;&gt;Star Rating &lt;img src=&quot;/images/racecards/star_3.gif&quot; alt=&quot;&quot;/&gt;&lt;/span&gt;&lt;/div&gt;">T</a></div>
# </td>
# <td class="silk"><img alt="Pink, navy blue collar and cuffs, quartered cap" src="/images/silks/20140429/20140429ncs202002.png"/></td>
# <td>13-2975<br/><a class="full_form" href="/form.aspx?id=2680730&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr" onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="_blank">Full form</a></td>
# <td class="horse"><a class="tooltip" href="/form.aspx?id=2680730&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr" onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for Keep It Dark form"><span class="horsename">Keep It Dark</span></a> 4 <span class="tooltip racestat" title="Won on this course">C</span><a class="tracker_popup" href="#" id="trid2680730" title="Keep It Dark">ATR Tracker</a><br/><span class="horseextrawrap"><span class="horseinfoicons"></span>b g Invincible Spirit - Tarneem (Zilzal)</span></td>
# <td>5 9 - 6</td>
# <td>
# <ul>
# <li class="jockey"><a class="tooltip" href="/form.aspx?id=1054947&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr&amp;type=J
#     " onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for Barry McHugh form">Barry McHugh</a></li>
# <li class="trainer"><a class="tooltip" href="/form.aspx?id=1372182&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr&amp;type=T
#     " onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for T Coyle form">T Coyle</a></li>
# </ul>
# </td>
# <td class="OR">69</td>
# </tr>
# <tr class="reviewtimeform">
# <td colspan="8"><strong>Timeform says</strong>: Last 2 wins have come here. Head carriage doesn't endear him to all but he didn't run badly at Doncaster last week and should give his running once again.<br/><span class="tfstarrating">Star Rating <img alt="" src="/images/racecards/star_3.gif"/></span></td>
# </tr>
# <tr class="">
# <td class=" cloth"><span class="number draw">3<em>(13)</em></span><div class="icons"><a class="summary tooltip" href="#" title="&lt;div class='longtext'&gt;He has won four times from 5f to 6f on good ground and on the all-weather. Beaten 8l behind Top Boy at 6-1 when eighth of 9 on his latest outing at Wolverhampton over 5f earlier this month.&lt;/div&gt;">i</a><a class="timeform tooltip" href="#" title="&lt;div class='longtext'&gt;&lt;strong&gt;Timeform says&lt;/strong&gt;: Resurgent third time up for this yard when runner-up at Lingfield in February and ended losing run when getting dream trip at that track last month. One to consider back on turf. &lt;span class=&quot;tfstarrating&quot;&gt;Star Rating &lt;img src=&quot;/images/racecards/star_4.gif&quot; alt=&quot;&quot;/&gt;&lt;/span&gt;&lt;/div&gt;">T</a></div>
# </td>
# <td class="silk"><img alt="Red, white seams, white and red chevrons on sleeves, white cap" src="/images/silks/20140429/20140429ncs202003.png"/></td>
# <td>062918<br/><a class="full_form" href="/form.aspx?id=2658589&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr" onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="_blank">Full form</a></td>
# <td class="horse"><a class="tooltip" href="/form.aspx?id=2658589&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr" onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for Profile Star form"><span class="horsename">Profile Star</span></a>
#             (IRE)
#            25 <span class="tooltip racestat" title="Won at this distance">D</span><a class="tracker_popup" href="#" id="trid2658589" title="Profile Star">ATR Tracker</a><br/><span class="horseextrawrap"><span class="horseinfoicons"><img class="tooltip" src="/images/racecards/p2_icon.png" title="Predictor Selection 2"/> </span>b g Kodiac - Fingal Nights (Night Shift)</span></td>
# <td>5 9 - 5</td>
# <td>
# <ul>
# <li class="jockey"><a class="tooltip" href="/form.aspx?id=1219887&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr&amp;type=J
#     " onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for D J Bates form">D J Bates <span class="tooltip" title="jockey is claiming 3 lbs for inexperience">
#                       (3)
#                     </span></a></li>
# <li class="trainer"><a class="tooltip" href="/form.aspx?id=1000072&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr&amp;type=T
#     " onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for Miss A Stokell form">Miss A Stokell</a></li>
# </ul>
# </td>
# <td class="OR">68</td>
# </tr>
# <tr class="reviewtimeform">
# <td colspan="8"><strong>Timeform says</strong>: Resurgent third time up for this yard when runner-up at Lingfield in February and ended losing run when getting dream trip at that track last month. One to consider back on turf.<br/><span class="tfstarrating">Star Rating <img alt="" src="/images/racecards/star_4.gif"/></span></td>
# </tr>
# <tr class="">
# <td class=" cloth"><span class="number draw">4<em>(1)</em></span><div class="icons"><a class="summary tooltip" href="#" title="&lt;div class='longtext'&gt;Successful at 5f and 6f on good to firm and good to soft ground. Won on her latest outing when 11-8fav at Redcar over 5f (good to soft) earlier this month, beating Britain by 3 1/2l.&lt;/div&gt;">i</a><a class="timeform tooltip" href="#" title="&lt;div class='longtext'&gt;&lt;strong&gt;Timeform says&lt;/strong&gt;: Maiden winner for Peter Chapple-Hyam in July and added to her tally (in cheekpieces, retained) when landing Redcar seller earlier in the month. Should give a good account back in handicap company. &lt;span class=&quot;tfstarrating&quot;&gt;Star Rating &lt;img src=&quot;/images/racecards/star_5.gif&quot; alt=&quot;&quot;/&gt;&lt;/span&gt;&lt;/div&gt;">T</a></div>
# </td>
# <td class="silk"><img alt="
lier this month.&lt;/div&gt;">i</a><a class="timeform tooltip" href="#" title="&lt;div class='longtext'&gt;&lt;strong&gt;Timeform says&lt;/strong&gt;: 3-time winner at Southwell in 2013 and solid effort on return to turf when third at Pontefract 2 weeks ago. Bit more needed here but should run his race. &lt;span class=&quot;tfstarrating&quot;&gt;Star Rating &lt;img src=&quot;/images/racecards/star_3.gif&quot; alt=&quot;&quot;/&gt;&lt;/span&gt;&lt;/div&gt;">T</a></div>
# </td>
# <td class="silk"><img alt="Royal blue, white stars, red sleeves, white armlets, white and royal blue striped cap" src="/images/silks/20140429/20140429ncs202007.png"/></td>
# <td>1-65233<br/><a class="full_form" href="/form.aspx?id=2658379&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr" onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="_blank">Full form</a></td>
# <td class="horse"><a class="tooltip" href="/form.aspx?id=2658379&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr" onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for Thorpe Bay form"><span class="horsename">Thorpe Bay</span></a> 15 <span class="tooltip racestat" title="Won at this distance">D</span><span class="tooltip racestat" title="Beaten favourite last time out">BF</span><a class="tracker_popup" href="#" id="trid2658379" title="Thorpe Bay">ATR Tracker</a><br/><span class="horseextrawrap"><span class="horseinfoicons"><img class="tooltip" src="/images/racecards/p1_icon.png" title="Predictor Selection 1"/> </span>b g Piccolo - My Valentina (Royal Academy)</span></td>
# <td>5 9 - 3</td>
# <td>
# <ul>
# <li class="jockey"><a class="tooltip" href="/form.aspx?id=1390579&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr&amp;type=J
#     " onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for Michael J M Murphy form">Michael J M Murphy <span class="tooltip" title="jockey is claiming 3 lbs for inexperience">
#                       (3)
#                     </span></a></li>
# <li class="trainer"><a class="tooltip" href="/form.aspx?id=1002337&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr&amp;type=T
#     " onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for M Appleby form">M Appleby</a></li>
# </ul>
# </td>
# <td class="OR">66</td>
# </tr>
# <tr class="reviewtimeform">
# <td colspan="8"><strong>Timeform says</strong>: 3-time winner at Southwell in 2013 and solid effort on return to turf when third at Pontefract 2 weeks ago. Bit more needed here but should run his race.<br/><span class="tfstarrating">Star Rating <img alt="" src="/images/racecards/star_3.gif"/></span></td>
# </tr>
# <tr class="">
# <td class=" cloth"><span class="number draw">8<em>(6)</em></span><div class="icons"><a class="summary tooltip" href="#" title="&lt;div class='longtext'&gt;A winner at 5f on good to soft ground. Beaten 9l behind Shillito at 20-1 when seventh of 13 on his latest outing at Pontefract over 5f (good) earlier this month.&lt;/div&gt;">i</a><a class="timeform tooltip" href="#" title="&lt;div class='longtext'&gt;&lt;strong&gt;Timeform says&lt;/strong&gt;: Hard to catch right for George Margarson and low-key start for new yard so far. Is becoming well treated but comes with risks attached. &lt;span class=&quot;tfstarrating&quot;&gt;Star Rating &lt;img src=&quot;/images/racecards/star_2.gif&quot; alt=&quot;&quot;/&gt;&lt;/span&gt;&lt;/div&gt;">T</a></div>
# </td>
# <td class="silk"><img alt="Royal blue, light blue chevron, armlets and cap" src="/images/silks/20140429/20140429ncs202008.png"/></td>
# <td>5789-87<br/><a class="full_form" href="/form.aspx?id=2729681&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr" onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="_blank">Full form</a></td>
# <td class="horse"><a class="tooltip" href="/form.aspx?id=2729681&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr" onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for Exotic Guest form"><span class="horsename">Exotic Guest</span></a> 15 <span class="tooltip racestat" title="Won at this course and this distance">CD</span><a class="tracker_popup" href="#" id="trid2729681" title="Exotic Guest">ATR Tracker</a><br/><span class="horseextrawrap"><span class="horseinfoicons"></span>ch g Bahamian Bounty - Mamoura (Lomond)</span></td>
# <td>4 9 - 2</td>
# <td>
# <ul>
# <li class="jockey"><a class="tooltip" href="/form.aspx?id=1001979&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr&amp;type=J
#     " onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for J P Sullivan form">J P Sullivan</a></li>
# <li class="trainer"><a class="tooltip" href="/form.aspx?id=1225587&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr&amp;type=T
#     " onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for Mrs R Carr form">Mrs R Carr</a></li>
# </ul>
# </td>
# <td class="OR">65</td>
# </tr>
# <tr class="reviewtimeform">
# <td colspan="8"><strong>Timeform says</strong>: Hard to catch right for George Margarson and low-key start for new yard so far. Is becoming well treated but comes with risks attached.<br/><span class="tfstarrating">Star Rating <img alt="" src="/images/racecards/star_2.gif"/></span></td>
# </tr>
# <tr class="">
# <td class=" cloth"><span class="number draw">9<em>(3)</em></span><div class="icons"><a class="summary tooltip" href="#" title="&lt;div class='longtext'&gt;Successful twice at 5f on good to soft and heavy ground. Finished 4l behind Boxing Shadows when fourth of 12 at 17-2 on her latest outing at Catterick over 5f (good) earlier this month.&lt;/div&gt;">i</a><a class="timeform tooltip" href="#" title="&lt;div class='longtext'&gt;&lt;strong&gt;Timeform says&lt;/strong&gt;: Improved when landing pair of Catterick 5f handicaps in October on good to soft/heavy. Better for reappearance when fourth there last week and should continue to give a good account. &lt;span class=&quot;tfstarrating&quot;&gt;Star Rating &lt;img src=&quot;/images/racecards/star_3.gif&quot; alt=&quot;&quot;/&gt;&lt;/span&gt;&lt;/div&gt;">T</a></div>
# </td>
# <td class="silk"><img alt="Purple, yellow chevron, sleeves and star on cap" src="/images/silks/20140429/20140429ncs202009.png"/></td>
# <td>0511-04<br/><a class="full_form" href="/form.aspx?id=2718613&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr" onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="_blank">Full form</a></td>
# <td class="horse"><a class="tooltip" href="/form.aspx?id=2718613&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr" onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for Fleurtille form"><span class="horsename">Fleurtille</span></a> 6 <span class="tooltip racestat" title="Won at this distance">D</span><a class="tracker_popup" href="#" id="trid2718613" title="Fleurtille">ATR Tracker</a><br/><span class="horseextrawrap"><span class="horseinfoicons"></span>b m Tillerman - Miss Fleurie (Alzao)</span></td>
# <td>5 8 - 13</td>
# <td>
# <ul>
# <li class="jockey"><a class="tooltip" href="/form.aspx?id=1403749&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr&amp;type=J
#     " onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for Connor Beasley form">Connor Beasley <span class="tooltip" title="jockey is claiming 5 lbs for inexperience">
#                       (5)
#                     </span></a></li>
# <li class="trainer"><a class="tooltip" href="/form.aspx?id=1001903&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr&amp;type=T
#     " onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for R Johnson form">R Johnson</a></li>
# </ul>
# </td>
# <td class="OR">62</td>
# </tr>
# <tr class="reviewtimeform">
# <td colspan="8"><strong>Timeform says</strong>: Improved when landing pair of Catterick 5f handicaps in October on good to soft/heavy. Better for reappearance when fourth there last week and should continue to give a good account.<br/><span class="tfstarrating">Star Rating <img alt="" src="/images/racecards/star_3.gif"/></span></td>
# </tr>
# <tr class="">
# <td class=" cloth"><span class="number draw">10<em>(8)</em></span><div class="icons"><a class="summary tooltip" href="#" title="&lt;div class='longtext'&gt;He has won three times from 5f to 6f on heavy ground and on the all-weather. Finished 4 1/2l behind Megaleka when fourth of 6 at 12-1 on his latest outing at Yarmouth over 5f (good) earlier this month.&lt;/div&gt;">i</a><a class="timeform tooltip" href="#" title="&lt;div class='longtext'&gt;&lt;strong&gt;Timeform says&lt;/strong&gt;: Scored off 5 lb higher AW mark at Kempton (6f) in October and not disgraced at Yarmouth recently. &lt;span class=&quot;tfstarrating&quot;&gt;Star Rating &lt;img src=&quot;/images/racecards/star_3.gif&quot; alt=&quot;&quot;/&gt;&lt;/span&gt;&lt;/div&gt;">T</a></div>
# </td>
# <td class="silk"><img alt="Royal blue and yellow diamonds, royal blue sleeves, yellow spots, quartered cap" src="/images/silks/20140429/20140429ncs202010.png"/></td>
# <td>10-9864<br/><a class="full_form" href="/form.aspx?id=2719750&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr" onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="_blank">Full form</a></td>
# <td class="horse"><a class="tooltip" href="/form.aspx?id=2719750&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr" onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for Harrogate Fair form"><span class="horsename">Harrogate Fair</span></a> 8 <span class="tooltip racestat" title="Won at this distance">D</span><a class="tracker_popup" href="#" id="trid2719750" title="Harrogate Fair">ATR Tracker</a><br/><span class="horseextrawrap"><span class="horseinfoicons"></span>b g Trade Fair - Starbeck (Spectrum)</span></td>
# <td>4 8 - 9</td>
# <td>
# <ul>
# <li class="jockey"><a class="tooltip" href="/form.aspx?id=1000974&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr&amp;type=J
#     " onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for J Fanning form">J Fanning</a></li>
# <li class="trainer"><a class="tooltip" href="/form.aspx?id=1227612&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr&amp;type=T
#     " onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for M D Squance form">M D Squance</a></li>
# </ul>
# </td>
# <td class="OR">58</td>
# </tr>
# <tr class="reviewtimeform">
# <td colspan="8"><strong>Timeform says</strong>: Scored off 5 lb higher AW mark at Kempton (6f) in October and not disgraced at Yarmouth recently.<br/><span class="tfstarrating">Star Rating <img alt="" src="/images/racecards/star_3.gif"/></span></td>
# </tr>
# <tr class="">
# <td class=" cloth"><span class="number draw">11<em>(12)</em></span><div class="icons"><a class="summary tooltip" href="#" title="&lt;div class='longtext'&gt;A winner at 5f on soft ground. Finished 11l behind Heartsong when last of 6 at 8-1 on her latest outing at Doncaster over 6f (soft) earlier this month. She is wearing blinkers for the first time.&lt;/div&gt;">i</a><a class="timeform tooltip" href="#" title="&lt;div class='longtext'&gt;&lt;strong&gt;Timeform says&lt;/strong&gt;: Very hit-and-miss last year and failed to beat a rival home in her 2 starts this year. Blinkers return now but comes with risks attached. &lt;span class=&quot;tfstarrating&quot;&gt;Star Rating &lt;img src=&quot;/images/racecards/star_2.gif&quot; alt=&quot;&quot;/&gt;&lt;/span&gt;&lt;/div&gt;">T</a></div>
# </td>
# <td class="silk"><img alt="Grey, red epaulets, checked sleeves and cap" src="/images/silks/20140429/20140429ncs202011.png"/></td>
# <td>0360-76<br/><a class="full_form" href="/form.aspx?id=2727259&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr" onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="_blank">Full form</a></td>
# <td class="horse"><a class="tooltip" href="/form.aspx?id=2727259&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr" onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for Balinka form"><span class="horsename">Balinka</span></a> 4 <span class="tooltip racestat" title="Won at this distance">D</span><a class="tracker_popup" href="#" id="trid2727259" title="Balinka">ATR Tracker</a><br/><span class="horseextrawrap"><span class="horseinfoicons"></span>b f Bahamian Bounty - Eurolinka (Tirol)</span></td>
# <td>4 8 - 7b<sup>1</sup></td>
# <td>
# <ul>
# <li class="jockey"><a class="tooltip" href="/form.aspx?id=1000046&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr&amp;type=J
#     " onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for D Allan form">D Allan</a></li>
# <li class="trainer"><a class="tooltip" href="/form.aspx?id=1002760&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr&amp;type=T
#     " onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for M Brittain form">M Brittain</a></li>
# </ul>
# </td>
# <td class="OR">56</td>
# </tr>
# <tr class="reviewtimeform">
# <td colspan="8"><strong>Timeform says</strong>: Very hit-and-miss last year and failed to beat a rival home in her 2 starts this year. Blinkers return now but comes with risks attached.<br/><span class="tfstarrating">Star Rating <img alt="" src="/images/racecards/star_2.gif"/></span></td>
# </tr>
# <tr class="">
# <td class=" cloth"><span class="number draw">12<em>(7)</em></span><div class="icons"><a class="summary tooltip" href="#" title="&lt;div class='longtext'&gt;He has won three times from 5f to 6f on firm and good to firm ground. Beaten 4 1/2l behind Compton Prince at 8-1 when eighth of 12 on his latest outing at Bath over 5f (good to firm) in September last year.&lt;/div&gt;">i</a><a class="timeform tooltip" href="#" title="&lt;div class='longtext'&gt;&lt;strong&gt;Timeform says&lt;/strong&gt;: Built on a couple of good efforts when ending a lengthy losing run at Bath in August. Not disgraced afterwards but best watched on seasonal reappearance. &lt;span class=&quot;tfstarrating&quot;&gt;Star Rating &lt;img src=&quot;/images/racecards/star_3.gif&quot; alt=&quot;&quot;/&gt;&lt;/span&gt;&lt;/div&gt;">T</a></div>
# </td>
# <td class="silk"><img alt="Red, red and royal blue diabolo on sleeves, quartered cap" src="/images/silks/20140429/20140429ncs202012.png"/></td>
# <td>241458-<br/><a class="full_form" href="/form.aspx?id=2514566&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr" onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="_blank">Full form</a></td>
# <td class="horse"><a class="tooltip" href="/form.aspx?id=2514566&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr" onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for Arch Walker form"><span class="horsename">Arch Walker</span></a>
#             (IRE)
#            211 <span class="tooltip racestat" title="Won on this course">C</span><span class="tooltip racestat" title="Won at this distance">D</span><a class="tracker_popup" href="#" id="trid2514566" title="Arch Walker">ATR Tracker</a><br/><span class="horseextrawrap"><span class="horseinfoicons"></span>ch g Choisir - Clunie (Inchinor)</span></td>
# <td>7 8 - 7</td>
# <td>
# <ul>
# <li class="jockey"><a class="tooltip" href="/form.aspx?id=1001509&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr&amp;type=J
#     " onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for J Quinn form">J Quinn</a></li>
# <li class="trainer"><a class="tooltip" href="/form.aspx?id=1000937&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr&amp;type=T
#     " onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for J R Weymes form">J R Weymes</a></li>
# </ul>
# </td>
# <td class="OR">56</td>
# </tr>
# <tr class="reviewtimeform">
# <td colspan="8"><strong>Timeform says</strong>: Built on a couple of good efforts when ending a lengthy losing run at Bath in August. Not disgraced afterwards but best watched on seasonal reappearance.<br/><span class="tfstarrating">Star Rating <img alt="" src="/images/racecards/star_3.gif"/></span></td>
# </tr>
# <tr class="">
# <td class=" cloth"><span class="number draw">13<em>(11)</em></span><div class="icons"><a class="summary tooltip" href="#" title="&lt;div class='longtext'&gt;Placed twice in nine starts. Beaten 8l behind Red Shadow at 7-1 when 11th of 12 on his latest outing at Wolverhampton over 6f in November last year. Runs from 3lb out of handicap. He is wearing blinkers for the first time.&lt;/div&gt;">i</a><a class="timeform tooltip" href="#" title="&lt;div class='longtext'&gt;&lt;strong&gt;Timeform says&lt;/strong&gt;: Modest maiden who ran well on last season's reappearance but who failed to build on it in 2 subsequent runs. Blinkers tried here but others have less to prove. &lt;span class=&quot;tfstarrating&quot;&gt;Star Rating &lt;img src=&quot;/images/racecards/star_3.gif&quot; alt=&quot;&quot;/&gt;&lt;/span&gt;&lt;/div&gt;">T</a></div>
# </td>
# <td class="silk"><img alt="Light green, brown braces and armlets, white cap" src="/images/silks/20140429/20140429ncs202013.png"/></td>
# <td>403/390-<br/><a class="full_form" href="/form.aspx?id=2726258&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr" onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="_blank">Full form</a></td>
# <td class="horse"><a class="tooltip" href="/form.aspx?id=2726258&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr" onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for Marabout form"><span class="horsename">Marabout</span></a>
#             (IRE)
#            165 <a class="tracker_popup" href="#" id="trid2726258" title="Marabout">ATR Tracker</a><br/><span class="horseextrawrap"><span class="horseinfoicons"></span>b g Haafhd - Nirvana (Marju)</span></td>
# <td>4 8 - 7b<sup>1</sup></td>
# <td>
# <ul>
# <li class="jockey"><a class="tooltip" href="/form.aspx?id=1002026&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr&amp;type=J
#     " onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for D Fentiman form">D Fentiman</a></li>
# <li class="trainer"><a class="tooltip" href="/form.aspx?id=1002760&amp;ref=cardmain&amp;dte=2014-04-29&amp;refsite=atr&amp;type=T
#     " onclick="OpenWindow(this.href,836,550,'','no','FormPopup');return false;" target="FormWin" title="click for M Brittain form">M Brittain</a></li>
# </ul>
# </td>
# <td class="OR">56<br/><img alt="Official Rating down -3 to 53 in future races
#
#     (+0 not including Long Handicap)
#     " class="tooltip" src="/images/racecards/ratings/minus3.gif" title="Official Rating down -3 to 53 in future races
#
#     (+0 not including Long Handicap)
#     "/></td>
# </tr>
# <tr class="reviewtimeform">
# <td colspan="8"><strong>Timeform says</strong>: Modest maiden who ran well on last season's reappearance but who failed to build on it in 2 subsequent runs. Blinkers tried here but others have less to prove.<br/><span class="tfstarrating">Star Rating <img alt="" src="/images/racecards/star_3.gif"/></span></td>
# </tr>

# %%
mydivs = soup.findAll("tr", { "class" : "reviewtimeform" })
print mydivs
# Out:
# [<tr class="reviewtimeform">
# <td colspan="8"><strong>Timeform says</strong>: Won 5f handicap at Ayr when last seen in October. Should remain competitive off this mark but entitled to need her first run back this year.<br/><span class="tfstarrating">Star Rating <img alt="" src="/images/racecards/star_3.gif"/></span></td>
# </tr>, <tr class="reviewtimeform">
# <td colspan="8"><strong>Timeform says</strong>: Last 2 wins have come here. Head carriage doesn't endear him to all but he didn't run badly at Doncaster last week and should give his running once again.<br/><span class="tfstarrating">Star Rating <img alt="" src="/images/racecards/star_3.gif"/></span></td>
# </tr>, <tr class="reviewtimeform">
# <td colspan="8"><strong>Timeform says</strong>: Resurgent third time up for this yard when runner-up at Lingfield in February and ended losing run when getting dream trip at that track last month. One to consider back on turf.<br/><span class="tfstarrating">Star Rating <img alt="" src="/images/racecards/star_4.gif"/></span></td>
# </tr>, <tr class="reviewtimeform">
# <td colspan="8"><strong>Timeform says</strong>: Maiden winner for Peter Chapple-Hyam in July and added to her tally (in cheekpieces, retained) when landing Redcar seller earlier in the month. Should give a good account back in handicap company.<br/><span class="tfstarrating">Star Rating <img alt="" src="/images/racecards/star_5.gif"/></span></td>
# </tr>, <tr class="reviewtimeform">
# <td colspan="8"><strong>Timeform says</strong>: Had a good year in 2013 but handicapped right up to his best as a result. Entitled to be sharper with this behind him.<br/><span class="tfstarrating">Star Rating <img alt="" src="/images/racecards/star_3.gif"/></span></td>
# </tr>, <tr class="reviewtimeform">
# <td colspan="8"><strong>Timeform says</strong>: Fair handicapper who registered her second victory of 2013 at Beverley in August. Not disgraced in defeat afterwards but first time out probably not the time to catch her.<br/><span class="tfstarrating">Star Rating <img alt="" src="/images/racecards/star_2.gif"/></span></td>
# </tr>, <tr class="reviewtimeform">
# <td colspan="8"><strong>Timeform says</strong>: 3-time winner at Southwell in 2013 and solid effort on return to turf when third at Pontefract 2 weeks ago. Bit more needed here but should run his race.<br/><span class="tfstarrating">Star Rating <img alt="" src="/images/racecards/star_3.gif"/></span></td>
# </tr>, <tr class="reviewtimeform">
# <td colspan="8"><strong>Timeform says</strong>: Hard to catch right for George Margarson and low-key start for new yard so far. Is becoming well treated but comes with risks attached.<br/><span class="tfstarrating">Star Rating <img alt="" src="/images/racecards/star_2.gif"/></span></td>
# </tr>, <tr class="reviewtimeform">
# <td colspan="8"><strong>Timeform says</strong>: Improved when landing pair of Catterick 5f handicaps in October on good to soft/heavy. Better for reappearance when fourth there last week and should continue to give a good account.<br/><span class="tfstarrating">Star Rating <img alt="" src="/images/racecards/star_3.gif"/></span></td>
# </tr>, <tr class="reviewtimeform">
# <td colspan="8"><strong>Timeform says</strong>: Scored off 5 lb higher AW mark at Kempton (6f) in October and not disgraced at Yarmouth recently.<br/><span class="tfstarrating">Star Rating <img alt="" src="/images/racecards/star_3.gif"/></span></td>
# </tr>, <tr class="reviewtimeform">
# <td colspan="8"><strong>Timeform says</strong>: Very hit-and-miss last year and failed to beat a rival home in her 2 starts this year. Blinkers return now but comes with risks attached.<br/><span class="tfstarrating">Star Rating <img alt="" src="/images/racecards/star_2.gif"/></span></td>
# </tr>, <tr class="reviewtimeform">
# <td colspan="8"><strong>Timeform says</strong>: Built on a couple of good efforts when ending a lengthy losing run at Bath in August. Not disgraced afterwards but best watched on seasonal reappearance.<br/><span class="tfstarrating">Star Rating <img alt="" src="/images/racecards/star_3.gif"/></span></td>
# </tr>, <tr class="reviewtimeform">
# <td colspan="8"><strong>Timeform says</strong>: Modest maiden who ran well on last season's reappearance but who failed to build on it in 2 subsequent runs. Blinkers tried here but others have less to prove.<br/><span class="tfstarrating">Star Rating <img alt="" src="/images/racecards/star_3.gif"/></span></td>
# </tr>]

# %%
for tr, x in enumerate(mydivs):
    print tr, "---------------", x.text
    print x.find("img")
# Out:
# 0 ---------------
# Timeform says: Won 5f handicap at Ayr when last seen in October. Should remain competitive off this mark but entitled to need her first run back this year.Star Rating
#
# <img alt="" src="/images/racecards/star_3.gif"/>
# 1 ---------------
# Timeform says: Last 2 wins have come here. Head carriage doesn't endear him to all but he didn't run badly at Doncaster last week and should give his running once again.Star Rating
#
# <img alt="" src="/images/racecards/star_3.gif"/>
# 2 ---------------
# Timeform says: Resurgent third time up for this yard when runner-up at Lingfield in February and ended losing run when getting dream trip at that track last month. One to consider back on turf.Star Rating
#
# <img alt="" src="/images/racecards/star_4.gif"/>
# 3 ---------------
# Timeform says: Maiden winner for Peter Chapple-Hyam in July and added to her tally (in cheekpieces, retained) when landing Redcar seller earlier in the month. Should give a good account back in handicap company.Star Rating
#
# <img alt="" src="/images/racecards/star_5.gif"/>
# 4 ---------------
# Timeform says: Had a good year in 2013 but handicapped right up to his best as a result. Entitled to be sharper with this behind him.Star Rating
#
# <img alt="" src="/images/racecards/star_3.gif"/>
# 5 ---------------
# Timeform says: Fair handicapper who registered her second victory of 2013 at Beverley in August. Not disgraced in defeat afterwards but first time out probably not the time to catch her.Star Rating
#
# <img alt="" src="/images/racecards/star_2.gif"/>
# 6 ---------------
# Timeform says: 3-time winner at Southwell in 2013 and solid effort on return to turf when third at Pontefract 2 weeks ago. Bit more needed here but should run his race.Star Rating
#
# <img alt="" src="/images/racecards/star_3.gif"/>
# 7 ---------------
# Timeform says: Hard to catch right for George Margarson and low-key start for new yard so far. Is becoming well treated but comes with risks attached.Star Rating
#
# <img alt="" src="/images/racecards/star_2.gif"/>
# 8 ---------------
# Timeform says: Improved when landing pair of Catterick 5f handicaps in October on good to soft/heavy. Better for reappearance when fourth there last week and should continue to give a good account.Star Rating
#
# <img alt="" src="/images/racecards/star_3.gif"/>
# 9 ---------------
# Timeform says: Scored off 5 lb higher AW mark at Kempton (6f) in October and not disgraced at Yarmouth recently.Star Rating
#
# <img alt="" src="/images/racecards/star_3.gif"/>
# 10 ---------------
# Timeform says: Very hit-and-miss last year and failed to beat a rival home in her 2 starts this year. Blinkers return now but comes with risks attached.Star Rating
#
# <img alt="" src="/images/racecards/star_2.gif"/>
# 11 ---------------
# Timeform says: Built on a couple of good efforts when ending a lengthy losing run at Bath in August. Not disgraced afterwards but best watched on seasonal reappearance.Star Rating
#
# <img alt="" src="/images/racecards/star_3.gif"/>
# 12 ---------------
# Timeform says: Modest maiden who ran well on last season's reappearance but who failed to build on it in 2 subsequent runs. Blinkers tried here but others have less to prove.Star Rating
#
# <img alt="" src="/images/racecards/star_3.gif"/>
